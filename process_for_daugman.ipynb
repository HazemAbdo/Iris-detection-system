# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
import process_for_daugman as pdf
from sobel import show_images
import matplotlib.pyplot as plt 
import skimage.io as io
import os
import numpy as np
paths=[]
def load_data(dir_name = 'images'):
        imgs = []
        print(os.listdir(dir_name))
        for filename in os.listdir(dir_name):
            paths.append(dir_name + '/' + filename)
        return paths
imgs = load_data('images')
IMG_PATH = 'images/kelvinl1.bmp'
for img in imgs:
    o_circles,inner_circles,im = pdf.process_for_daugman(pdf,img)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['aeval1.bmp', 'kelvinl1.bmp', 'kelvinl3.bmp', 'kelvinr3.bmp', 'mazwanl1.bmp', 'mazwanl2.bmp', 'mazwanl3.bmp', 'mazwanl4.bmp', 'mazwanl5.bmp', 'mazwanr1.bmp', 'mazwanr2.bmp', 'mazwanr3.bmp', 'mazwanr4.bmp', 'mazwanr5.bmp', 'roslir2.bmp', 'ss.bmp', 'tanwnl3.bmp']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9f9097d85633> in <module>
#      21 IMG_PATH = 'images/kelvinl1.bmp'
#      22 for img in imgs:
# ---> 23     o_circles,inner_circles,im = pdf.process_for_daugman(pdf,img)
#
# c:\Users\hazem\Desktop\imgProject\code\Iris-Recoginition-System\process_for_daugman.py in process_for_daugman(self, IMG_PATH)
#     185     output_image = Image.new("RGB", Image.open(IMG_PATH).size)
#     186     output_image.paste(Image.open(IMG_PATH))
# --> 187     i_y, i_x, i_r = self.searchInnerBound(img)
#     188     draw_result = ImageDraw.Draw(output_image)
#     189     draw_result.ellipse(
#
# c:\Users\hazem\Desktop\imgProject\code\Iris-Recoginition-System\process_for_daugman.py in searchInnerBound(img)
#      67     r = inner_r - jump + r
#      68
# ---> 69     hs = ContourIntegralCircular(img, y, x, r, angs)
#      70
#      71     # Hough Space Partial Derivative R
#
# c:\Users\hazem\Desktop\imgProject\code\Iris-Recoginition-System\process_for_daugman.py in ContourIntegralCircular(imagen, y_0, x_0, r, angs)
#     160     for i in range(len(angs)):
#     161         ang = angs[i]
# --> 162         y[i, :, :, :] = np.round(y_0 + np.cos(ang) * r).astype(int)
#     163         x[i, :, :, :] = np.round(x_0 + np.sin(ang) * r).astype(int)
#     164
#
# KeyboardInterrupt:
